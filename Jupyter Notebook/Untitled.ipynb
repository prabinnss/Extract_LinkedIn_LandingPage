# %%
from selenium import webdriver
import pandas as pd
import numpy as np
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import itertools
import time
import openpyxl
from openpyxl import load_workbook
from openpyxl.worksheet.hyperlink import Hyperlink

# %%
def LinkedIn_Search(person_name):
    driver = webdriver.Chrome('/Users/Prabin/Repository/LinkdIn Scrapping/Jupyter Notebook/chromedriver')
    google_url = 'https://www.google.com/'
    driver.get(google_url)
    time.sleep(5)
    WebDriverWait(driver, 60).until(EC.element_to_be_clickable((By.NAME, 'q')))
    search_query = f'CPA {person_name} LinkedIn Profile Virginia USA'
    search_box = driver.find_element(By.NAME, 'q')
    search_box.send_keys(search_query)
    search_box.submit()
    time.sleep(5)
    try:
        WebDriverWait(driver, 60).until(EC.presence_of_element_located((By.XPATH, '//a[contains(@href, "linkedin.com/in/")]')))
        linkedin_link = driver.find_element(By.XPATH, '//a[contains(@href, "linkedin.com/in/")]').get_attribute('href')
        landing_page=(linkedin_link)
        return landing_page
    except Exception as e:
        print("LinkedIn profile not found or search results took too long to load.")
        linkedin_link = None
        return None

        # Closing the browser
    print(landing_page)
    driver.quit()

# %%
excel_file_path=''
def update_excel_with_linkedin_links(excel_file):
    # Load Excel file
    pd_xl_file = pd.ExcelFile(excel_file_path)
    
    # Assuming the sheet is named 'Sheet1' (you can adjust this if necessary)
    df = pd_xl_file.parse('Sheet1')
    
    # Assuming 'Person Name' is in the first column (index 0)
    person_names = df.iloc[:, 0]
    
    # Create an empty list to hold LinkedIn URLs
    linkedin_urls = []
    
    # Loop over each person and get their LinkedIn profile
    for person_name in person_names:
        print(f'Searching for LinkedIn profile of {person_name}')
        linkedin_url = LinkedIn_Search(person_name)
        if linkedin_url:
            print(f'Found LinkedIn URL: {linkedin_url}')
        else:
            print(f'No LinkedIn URL found for {person_name}')
        linkedin_urls.append(linkedin_url)
    
        # Load the existing workbook and the specific sheet you want to update
        workbook = load_workbook(excel_file_path)
        sheet = workbook.active

        # Assuming LinkedIn URLs should be written in column 2 (B)
        for row_num, linkedin_url in enumerate(linkedin_urls, start=2):  # Assuming the first row is header
            sheet.cell(row=row_num, column=2).hyperlink=linkedin_url

        # Save the updated Excel file
        workbook.save(excel_file_path)
        print('Excel file updated with LinkedIn URLs.')

# %%
# File path to the Excel file
excel_file_path = "/Users/Prabin/Repository/LinkdIn Scrapping/Excel Files/CPA List.xlsx"

# update the Excel file
update_excel_with_linkedin_links(excel_file_path)
# Out:
# Searching for LinkedIn profile of Pouya Hojjat
# Found LinkedIn URL: https://www.linkedin.com/in/pouya-hojjat
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of PRADEEP K SAHAJWALLA
# Found LinkedIn URL: https://www.linkedin.com/in/pradeep-sahajwalla-7380ba148
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pradeep Pokharel
# Found LinkedIn URL: https://www.linkedin.com/in/pradeep-pokharel-cpa-306a5a18
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pradipsingh Surjeetsingh Bhogal
# Found LinkedIn URL: https://www.linkedin.com/in/pradip-singh-bhogal-cpa-cia-cgap-ccsa-ea-549624163
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pradipti Rajbhandari
# Found LinkedIn URL: https://www.linkedin.com/in/pradipti-rajbhandari-a1129826
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prajaya Pathak
# Found LinkedIn URL: https://www.linkedin.com/in/praz-pathak-cpa-mba-b09a04a2
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prakash Chandrabalan
# Found LinkedIn URL: https://www.linkedin.com/in/kyle-timmermann-68b4744b
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of PRAKASH RAMACHANDRAN
# Found LinkedIn URL: https://www.linkedin.com/in/prakash-ramchandran-187425203
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pramit Jashubhai Patel
# LinkedIn profile not found or search results took too long to load.
# No LinkedIn URL found for Pramit Jashubhai Patel
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pramod M Gupte
# Found LinkedIn URL: https://www.linkedin.com/in/pramod-gupte-8b17b538
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pranit Karky
# Found LinkedIn URL: https://www.linkedin.com/in/pranitkarky
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prasada Rao Tripuramallu
# Found LinkedIn URL: https://in.linkedin.com/in/prasada-rao-p-6098b828
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prasadini E. Bogollagama
# Found LinkedIn URL: https://www.linkedin.com/in/prasadini-bogollagama-0727874
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prashant Dhingra
# Found LinkedIn URL: https://www.linkedin.com/in/prashant-shawn-dhingra-cpa-4b573a37
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prashant S. Rathore
# Found LinkedIn URL: https://www.linkedin.com/in/prashant-rathore-56579163
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pratik M Shah
# Found LinkedIn URL: https://www.linkedin.com/in/pratikshah-cpa-33a0b02
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pratipal Shakya
# Found LinkedIn URL: https://www.linkedin.com/in/shova-shakya-76024212
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pravakar Dhungana
# Found LinkedIn URL: https://www.linkedin.com/in/pravakar-dhungana-cpa-09745845
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Praxi Mittal
# Found LinkedIn URL: https://www.linkedin.com/in/rashimittalcpa
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preet Mohinder Singh Virk
# Found LinkedIn URL: https://www.linkedin.com/in/pvirk345
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preetha Sudhakar Iyer
# Found LinkedIn URL: https://www.linkedin.com/in/preetha-iyer-b6b92a175
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preeti Arun Tilve Krzystofik
# LinkedIn profile not found or search results took too long to load.
# No LinkedIn URL found for Preeti Arun Tilve Krzystofik
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prema Vivek
# Found LinkedIn URL: https://www.linkedin.com/in/vivekr-rao
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Premalatha Nair
# Found LinkedIn URL: https://www.linkedin.com/in/latha-nair-44904720
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pressley Merchant
# Found LinkedIn URL: https://www.linkedin.com/in/pressley-merchant-cpa-4a774058
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston Allan Jones
# Found LinkedIn URL: https://www.linkedin.com/in/preston-jones-703a2421a
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston C Cleland
# Found LinkedIn URL: https://www.linkedin.com/in/preston-cleland-902212
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston G. Hasting
# Found LinkedIn URL: https://www.linkedin.com/in/preston-hasting-729a25138
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston H Evers
# Found LinkedIn URL: https://www.linkedin.com/in/preston-evers-cpa-1045968
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston Lane Porterfield
# Found LinkedIn URL: https://www.linkedin.com/in/kevin-lane-a28b21139
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston Matthew Scott Smith
# Found LinkedIn URL: https://www.linkedin.com/in/preston-smith-cpa-85019957
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preston Tyler Smith
# Found LinkedIn URL: https://www.linkedin.com/in/preston-smith-cpa-85019957
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preya Patel Saroop
# Found LinkedIn URL: https://www.linkedin.com/in/preya-patel-saroop-0501b489
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Preyanshibahen J Patel
# Found LinkedIn URL: https://www.linkedin.com/in/preyanshi
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prince Henry Quarshie
# Found LinkedIn URL: https://www.linkedin.com/in/prince-henry-quarshie-a36aa214
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscila Ramos Martins Kubach
# LinkedIn profile not found or search results took too long to load.
# No LinkedIn URL found for Priscila Ramos Martins Kubach
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Anne Liesau Martin
# Found LinkedIn URL: https://www.linkedin.com/in/priscillaamartin
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Bujtas Tynch
# Found LinkedIn URL: https://www.linkedin.com/in/priscillatynch
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Bullock
# Found LinkedIn URL: https://www.linkedin.com/in/priscilla-bullock-00839b27
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Gail Verhaagen
# Found LinkedIn URL: https://www.linkedin.com/in/gail-verhaagen-cpa-42661551
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Hoi-Yan Lam
# Found LinkedIn URL: https://www.linkedin.com/in/priscilla-lam-12191b85
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Mary Gharai
# Found LinkedIn URL: https://www.linkedin.com/in/priscilla-gharai-29624125
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priscilla Neher Myerson
# Found LinkedIn URL: https://www.linkedin.com/in/priscilla-myerson-3a34531a
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prithish David
# Found LinkedIn URL: https://www.linkedin.com/in/prithish-david-05b6a8155
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priti Dinu Patel
# Found LinkedIn URL: https://www.linkedin.com/in/priti-patel-41702870
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of PRIYA BASKARAN
# Found LinkedIn URL: https://www.linkedin.com/in/priya-baskaran-710b297
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priya Chenthil
# Found LinkedIn URL: https://www.linkedin.com/in/priya-chenthil-2a1796169
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priya Rahul Dhareshwar
# Found LinkedIn URL: https://www.linkedin.com/in/priya-dhareshwar-cpa-46592212
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priya Sharma
# Found LinkedIn URL: https://www.linkedin.com/in/priya-sharma-cpa-mba-92262232
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priyanka Chandgothia
# Found LinkedIn URL: https://www.linkedin.com/in/priyanka-chandgothia-5b1b1917
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priyanka Pal
# Found LinkedIn URL: https://www.linkedin.com/in/priyanka-pal-82430221b
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of PRIYANKA PATIL
# Found LinkedIn URL: https://www.linkedin.com/in/priyanka-patel-7b57b7187
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priyanka Rayapudi
# Found LinkedIn URL: https://www.linkedin.com/in/priyankarayapudi
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priyanka Sharma
# Found LinkedIn URL: https://www.linkedin.com/in/priyanka--sharma
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Priyanka Sood
# Found LinkedIn URL: https://www.linkedin.com/in/priyankasoodcpa
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Prutha Talati
# Found LinkedIn URL: https://www.linkedin.com/in/pruthatalati
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pryde Fru Atanga
# Found LinkedIn URL: https://www.linkedin.com/in/pryde-atanga-49753b33
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pui-Yin Li
# Found LinkedIn URL: https://www.linkedin.com/in/yingying-lillian-gu-443935a9
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Punita Ahuja
# Found LinkedIn URL: https://www.linkedin.com/in/punitaahujacpa
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Pura Maria Molina
# Found LinkedIn URL: https://www.linkedin.com/in/pura-molina-939ba162
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Purshottam M Vachhani
# Found LinkedIn URL: https://www.linkedin.com/in/percy-vachhani-14584a14
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qi Li
# Found LinkedIn URL: https://www.linkedin.com/in/qili1
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qi Liu
# Found LinkedIn URL: https://www.linkedin.com/in/qi-liu-cpa-55322183
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qi X Kuang
# Found LinkedIn URL: https://ca.linkedin.com/in/chuqikuang
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of qi zeng
# Found LinkedIn URL: https://www.linkedin.com/in/qi-sonia-zeng-cpa-8122a5a7
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qi Zhang
# Found LinkedIn URL: https://www.linkedin.com/in/qi-zhang-8867671
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qian Cai
# Found LinkedIn URL: https://www.linkedin.com/in/qian-cai-6485b0b
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qian Thacker
# Found LinkedIn URL: https://www.linkedin.com/in/sylvia-thacker-cpa
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qian Zhang
# Found LinkedIn URL: https://www.linkedin.com/in/qian-zhang-3729356a
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qian Zhao
# Found LinkedIn URL: https://www.linkedin.com/in/qian-zhao-7b550153
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qianchang Chen
# Found LinkedIn URL: https://www.linkedin.com/in/virginia-chen-cpa-71105680
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qianyu Tan
# Found LinkedIn URL: https://www.linkedin.com/in/isaac-tan-cpa-b2232773
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qianyue Zhang
# Found LinkedIn URL: https://www.linkedin.com/in/qianyue-zhang-cpa
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiaoqiao Chen
# Found LinkedIn URL: https://www.linkedin.com/in/qiaoqiao-chen-65063b307?trk=people-guest_people_search-card
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiaoqing Qiu
# Found LinkedIn URL: https://www.linkedin.com/in/brinky-qiu-cpa-ab486a39
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qier Tan
# Found LinkedIn URL: https://www.linkedin.com/in/qiertan
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qihang Sabrina Liu
# Found LinkedIn URL: https://www.linkedin.com/in/sabrinaliu
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qing Cao
# Found LinkedIn URL: https://www.linkedin.com/in/lily-cao-0306801a3
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qing Christy Li
# Found LinkedIn URL: https://www.linkedin.com/in/christy-li-70746510
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qing Guo
# Found LinkedIn URL: https://www.linkedin.com/in/qing-guo-129b71191
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qing Lin
# Found LinkedIn URL: https://www.linkedin.com/in/qinglin-cpa
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qing Xue
# Found LinkedIn URL: https://www.linkedin.com/in/xueqing/en
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qingqing Grace Cao
# Found LinkedIn URL: https://www.linkedin.com/in/q-grace-cao-cpa-b80967a
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of QINGRAN FENG
# Found LinkedIn URL: https://www.linkedin.com/in/qingranfeng
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qingxin Cai
# Found LinkedIn URL: https://www.linkedin.com/in/qingxin-dave-cai-99a01a134
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiong Wang
# Found LinkedIn URL: https://www.linkedin.com/in/qiong-wang-65583a5
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiong zhou Martin
# Found LinkedIn URL: https://www.linkedin.com/in/qinzhou
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of QIQI DENG
# Found LinkedIn URL: https://www.linkedin.com/in/qiqi-deng-5a4782b
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiqi Wei
# Found LinkedIn URL: https://www.linkedin.com/in/qiqi-wei-cpa-1a581924
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiu Shi
# Found LinkedIn URL: https://www.linkedin.com/in/xinyi-qiu-cpa-apr41
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiu Ying Liu
# Found LinkedIn URL: https://www.linkedin.com/in/ying-liu-cpa-1a239663
# Excel file updated with LinkedIn URLs.
# Searching for LinkedIn profile of Qiu Zhao
# Found LinkedIn URL: https://www.linkedin.com/in/321426
# Excel file updated with LinkedIn URLs.
